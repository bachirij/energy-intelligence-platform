# %% [markdown]
# # Electricity Demand & Weather Proprecessing
#
# This notebook explains step by step how the preprocessing pipeline works to build a clean, continuous, hourly dataset combining:
#
# - Electricity demand (load_MW)
# - Weather variables

# %% [markdown]
# # 1. Context & Objectives
#
# We start from raw time series data that may contain:
# - Missing timestamps
# - Irregular hourly frequency
# - Gaps (NaNs)
#
# ### Final objectives:
# - Ensure a complete hourly timeline
# - Interpolate numeric variables only
# - Safely handle categorical variables
# - Merge demand and weather into a single dataset
# - Produce a model‑ready dataset

# %% [markdown]
# # 2. Imports & Project Structure

# %%
import pandas as pd

# %%
RAW_BASE_PATH = "../data/raw"
PROCESSED_BASE_PATH = "../data/processed"

# %% [markdown]
# # 3. Load Raw Data

# %%
country = "FR"
year = 2015

# Raw file paths
demand_path = f"{RAW_BASE_PATH}/electricity_demand/country={country}/year={year}/demand.parquet"
weather_path = f"{RAW_BASE_PATH}/weather/country={country}/year={year}/weather.parquet"

# Load dataframes
df_demand = pd.read_parquet(demand_path)
df_weather = pd.read_parquet(weather_path)

# %%
df_demand.head()
# Out:
#                    datetime  load_MW country
# 0 2015-01-01 00:00:00+00:00  70929.0      FR
# 1 2015-01-01 01:00:00+00:00  69773.0      FR
# 2 2015-01-01 02:00:00+00:00  66417.0      FR
# 3 2015-01-01 03:00:00+00:00  64182.0      FR
# 4 2015-01-01 04:00:00+00:00  63859.0      FR

# %%
df_demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8741 entries, 0 to 8740
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  8741 non-null   datetime64[ns, UTC]
#  1   load_MW   8741 non-null   float64
#  2   country   8741 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), object(1)
# memory usage: 205.0+ KB

# %%
df_weather.head()
# Out:
#                    datetime  temperature_2m  relative_humidity_2m  \
# 0 2015-01-01 00:00:00+00:00          -0.646             97.476974
# 1 2015-01-01 01:00:00+00:00          -0.946             97.470795
# 2 2015-01-01 02:00:00+00:00          -1.096             97.825935
# 3 2015-01-01 03:00:00+00:00          -1.846             97.812531
# 4 2015-01-01 04:00:00+00:00          -3.196             97.423698
#
#    wind_speed_10m  shortwave_radiation_instant country
# 0        2.968636                          0.0      FR
# 1        4.213692                          0.0      FR
# 2        5.400000                          0.0      FR
# 3        6.638072                          0.0      FR
# 4        5.351785                          0.0      FR

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   datetime                     8760 non-null   datetime64[ns, UTC]
#  1   temperature_2m               8760 non-null   float32
#  2   relative_humidity_2m         8760 non-null   float32
#  3   wind_speed_10m               8760 non-null   float32
#  4   shortwave_radiation_instant  8760 non-null   float32
#  5   country                      8760 non-null   object
# dtypes: datetime64[ns, UTC](1), float32(4), object(1)
# memory usage: 273.9+ KB

# %% [markdown]
# # 4. Helper functions

# %%
# Build a full hourly time index
def build_full_hourly_index(df: pd.DataFrame, time_col: str) -> pd.DatetimeIndex:
    """
    Build a complete hourly DatetimeIndex between min and max timestamps.
    """
    return pd.date_range(
    start=df[time_col].min(),
    end=df[time_col].max(),
    freq="h"
)

# %% [markdown]
# Why this matters?
# - Models expect regular time steps,
# - Missing hours must be explicitly created before interpolation

# %%
# Reindex & interpolate a time series
def reindex_and_interpolate_ts(
    df: pd.DataFrame,
    time_col: str,
    numeric_cols: list[str],
    categorical_cols: list[str] | None = None,
) -> pd.DataFrame:

    df = (
        df
        .drop_duplicates(subset=time_col)
        .sort_values(time_col)
        .copy()
    )

    df[time_col] = pd.to_datetime(df[time_col])

    full_index = build_full_hourly_index(df, time_col)

    df = (
        df
        .set_index(time_col)
        .reindex(full_index)
    )

    df[numeric_cols] = (
        df[numeric_cols]
        .interpolate(method="time", limit_area="inside")
    )

    if categorical_cols:
        df[categorical_cols] = (
            df[categorical_cols]
            .ffill()
            .bfill()
        )

    df = (
        df
        .rename_axis(time_col)
        .reset_index()
    )

    assert df[time_col].is_monotonic_increasing

    return df

# %% [markdown]
# # 5. Functions application

# %% [markdown]
# ## 5.1. Demand data

# %%
df_demand_processed = reindex_and_interpolate_ts(
df=df_demand,
time_col="datetime",
numeric_cols=["load_MW"],
categorical_cols=["country"]
)

# %%
df_demand_processed.head()

# %%
df_demand_processed.info()

# %%
df_demand_processed.isna().sum()

# %% [markdown]
# ## 5.2. Weather data

# %%
weather_cols = [
"temperature_2m",
"relative_humidity_2m",
"wind_speed_10m",
"shortwave_radiation_instant"
]

df_weather_processed = reindex_and_interpolate_ts(
df=df_weather,
time_col="datetime",
numeric_cols=weather_cols
)

# %%
df_weather_processed.head()

# %% [markdown]
# # 6. Merge Demand & Weather DataFrames

# %%
# Weather: drop redundant metadata
df_weather_processed = df_weather_processed.drop(columns=["country"])

df_merged = df_demand_processed.merge(
df_weather_processed,
on="datetime",
how="inner"
)

# Add metadata
df_merged["year"] = year

# %%
df_merged.head()

# %%
df_merged.info()

# %% [markdown]
# # 7. Final Data Quality Checks

# %%
# No missing values
assert df_merged.isna().sum().sum() == 0

# Strict hourly continuity
assert df_merged['datetime'].diff().dropna().unique()[0] == pd.Timedelta('1h')

# %% [markdown]
# The dataset is now clean, regular and model-ready.
#
# This preprocessing logic is reused as-is inside the production script src/preprocessing/build_preprocessed_dataset.py.
